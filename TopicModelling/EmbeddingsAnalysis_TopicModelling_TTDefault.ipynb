# %% [markdown]
# <a href="https://colab.research.google.com/github/raz0208/Natural-Language-Processing-Practices/blob/main/TopicModelling/EmbeddingsAnalysis_TopicModelling_TTDefault.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Topic Modelling

# %% [markdown]
# ## Semantic Signal Separation

# %%
# !pip install turftopic
# Out:
# Requirement already satisfied: turftopic in /usr/local/lib/python3.11/dist-packages (0.17.1)
# Requirement already satisfied: huggingface-hub<1.0.0,>=0.23.2 in /usr/local/lib/python3.11/dist-packages (from turftopic) (0.32.4)
# Requirement already satisfied: igraph<0.12.0,>=0.11.6 in /usr/local/lib/python3.11/dist-packages (from turftopic) (0.11.8)
# Requirement already satisfied: joblib<2.0.0,>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from turftopic) (1.5.1)
# Requirement already satisfied: numpy>=1.23.0 in /usr/local/lib/python3.11/dist-packages (from turftopic) (2.0.2)
# Requirement already satisfied: pillow<10.5.0,>=10.4.0 in /usr/local/lib/python3.11/dist-packages (from turftopic) (10.4.0)
# Requirement already satisfied: rich<14.0.0,>=13.6.0 in /usr/local/lib/python3.11/dist-packages (from turftopic) (13.9.4)
# Requirement already satisfied: scikit-learn<2.0.0,>=1.3.0 in /usr/local/lib/python3.11/dist-packages (from turftopic) (1.6.1)
# Requirement already satisfied: scipy<2.0.0,>=1.10.0 in /usr/local/lib/python3.11/dist-packages (from turftopic) (1.15.3)
# Requirement already satisfied: sentence-transformers>=2.2.0 in /usr/local/lib/python3.11/dist-packages (from turftopic) (4.1.0)
# Requirement already satisfied: torch<3.0.0,>=2.1.0 in /usr/local/lib/python3.11/dist-packages (from turftopic) (2.6.0+cu124)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from huggingface-hub<1.0.0,>=0.23.2->turftopic) (3.18.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub<1.0.0,>=0.23.2->turftopic) (2025.3.2)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub<1.0.0,>=0.23.2->turftopic) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub<1.0.0,>=0.23.2->turftopic) (6.0.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from huggingface-hub<1.0.0,>=0.23.2->turftopic) (2.32.3)
# Requirement already satisfied: tqdm>=4.42.1 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub<1.0.0,>=0.23.2->turftopic) (4.67.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub<1.0.0,>=0.23.2->turftopic) (4.14.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.2 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub<1.0.0,>=0.23.2->turftopic) (1.1.2)
# Requirement already satisfied: texttable>=1.6.2 in /usr/local/lib/python3.11/dist-packages (from igraph<0.12.0,>=0.11.6->turftopic) (1.7.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.11/dist-packages (from rich<14.0.0,>=13.6.0->turftopic) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.11/dist-packages (from rich<14.0.0,>=13.6.0->turftopic) (2.19.1)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn<2.0.0,>=1.3.0->turftopic) (3.6.0)
# Requirement already satisfied: transformers<5.0.0,>=4.41.0 in /usr/local/lib/python3.11/dist-packages (from sentence-transformers>=2.2.0->turftopic) (4.52.4)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch<3.0.0,>=2.1.0->turftopic) (3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch<3.0.0,>=2.1.0->turftopic) (3.1.6)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch<3.0.0,>=2.1.0->turftopic) (12.4.127)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch<3.0.0,>=2.1.0->turftopic) (12.4.127)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch<3.0.0,>=2.1.0->turftopic) (12.4.127)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /usr/local/lib/python3.11/dist-packages (from torch<3.0.0,>=2.1.0->turftopic) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.4.5.8 in /usr/local/lib/python3.11/dist-packages (from torch<3.0.0,>=2.1.0->turftopic) (12.4.5.8)
# Requirement already satisfied: nvidia-cufft-cu12==11.2.1.3 in /usr/local/lib/python3.11/dist-packages (from torch<3.0.0,>=2.1.0->turftopic) (11.2.1.3)
# Requirement already satisfied: nvidia-curand-cu12==10.3.5.147 in /usr/local/lib/python3.11/dist-packages (from torch<3.0.0,>=2.1.0->turftopic) (10.3.5.147)
# Requirement already satisfied: nvidia-cusolver-cu12==11.6.1.9 in /usr/local/lib/python3.11/dist-packages (from torch<3.0.0,>=2.1.0->turftopic) (11.6.1.9)
# Requirement already satisfied: nvidia-cusparse-cu12==12.3.1.170 in /usr/local/lib/python3.11/dist-packages (from torch<3.0.0,>=2.1.0->turftopic) (12.3.1.170)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch<3.0.0,>=2.1.0->turftopic) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch<3.0.0,>=2.1.0->turftopic) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch<3.0.0,>=2.1.0->turftopic) (12.4.127)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch<3.0.0,>=2.1.0->turftopic) (12.4.127)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.11/dist-packages (from torch<3.0.0,>=2.1.0->turftopic) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch<3.0.0,>=2.1.0->turftopic) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch<3.0.0,>=2.1.0->turftopic) (1.3.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.11/dist-packages (from markdown-it-py>=2.2.0->rich<14.0.0,>=13.6.0->turftopic) (0.1.2)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.11/dist-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers>=2.2.0->turftopic) (2024.11.6)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in /usr/local/lib/python3.11/dist-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers>=2.2.0->turftopic) (0.21.1)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.11/dist-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers>=2.2.0->turftopic) (0.5.3)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch<3.0.0,>=2.1.0->turftopic) (3.0.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface-hub<1.0.0,>=0.23.2->turftopic) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface-hub<1.0.0,>=0.23.2->turftopic) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface-hub<1.0.0,>=0.23.2->turftopic) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface-hub<1.0.0,>=0.23.2->turftopic) (2025.4.26)

# %%
# Import required libraries
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import torch

# import model and turftopic libraries
from transformers import AutoTokenizer, AutoModel
from sentence_transformers import SentenceTransformer
from turftopic import SemanticSignalSeparation
import plotly.express as px

# %%
# Read and load dataset
dataset = pd.read_csv('gdb_abstract.csv')

# Show the datasets
### Abstract Embeddings Sample Dataset
print('Node Content:', dataset.shape)
print(dataset)
# Out:
# Node Content: (1000, 4)
#      Unnamed: 0                                              title  \
# 0             0  Phenotypic variability of Niemann-Pick disease...
# 1             1  Recurrent hypoglycemia secondary to metformin ...
# 2             2  Adaptation of the Ambulatory and Home Care Rec...
# 3             3  Multidimensional family therapy in adolescents...
# 4             4  Balanced crystalloids versus isotonic saline i...
# ..          ...                                                ...
# 995         995  Molecular Sex Identification in Dioecious  Hip...
# 996         996  Antimicrobial Peptides: Powerful Biorecognitio...
# 997         997  Analysis of Metabolites in White Flowers of  M...
# 998         998  Improved Cold Tolerance of Mango Fruit with En...
# 999         999  Characterization of the Complete Chloroplast G...
#
#                                               abstract  year
# 0    Background Niemann-Pick disease type C (NPC) i...  2018
# 1    Background Metformin toxicity is well known to...  2018
# 2    Background Measuring service use and costs is ...  2018
# 3    Background Substance use and delinquency are c...  2018
# 4    Objectives Intravenous fluids are one of the m...  2018
# ..                                                 ...   ...
# 995  The dioecious property of the sea buckthorn ( ...  2018
# 996  Bacterial infections represent a serious threa...  2018
# 997  A total of seven phenolics and 44 metabolites ...  2018
# 998  Red fruits were suggested to be tolerant to co...  2018
# 999  Buddleja colvilei Hook.f. & Thomson (Scrophula...  2018
#
# [1000 rows x 4 columns]

# %%
# Extract only the 'abstract' column and drop others
abstracts = dataset['abstract'].dropna().reset_index(drop=True)

# Display a few samples to verify
print(abstracts)
# Out:
# 0      Background Niemann-Pick disease type C (NPC) i...
# 1      Background Metformin toxicity is well known to...
# 2      Background Measuring service use and costs is ...
# 3      Background Substance use and delinquency are c...
# 4      Objectives Intravenous fluids are one of the m...
#                              ...
# 995    The dioecious property of the sea buckthorn ( ...
# 996    Bacterial infections represent a serious threa...
# 997    A total of seven phenolics and 44 metabolites ...
# 998    Red fruits were suggested to be tolerant to co...
# 999    Buddleja colvilei Hook.f. & Thomson (Scrophula...
# Name: abstract, Length: 1000, dtype: object

# %%
encoder = SentenceTransformer("paraphrase-MiniLM-L12-v2")
embeddings = encoder.encode(abstracts, show_progress_bar=True)
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# modules.json:   0%|          | 0.00/229 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/122 [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/3.52k [00:00<?, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/631 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/133M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/316 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]
# Batches:   0%|          | 0/32 [00:00<?, ?it/s]

# %%
embeddings
# Out:
# array([[-0.18085335, -0.02877346, -0.01457151, ...,  0.25280115,
#          0.00423292, -0.11268158],
#        [-0.09924358, -0.01678822, -0.02370374, ...,  0.08323223,
#          0.04386293, -0.17668416],
#        [ 0.07698026, -0.10633833, -0.03089516, ...,  0.23365116,
#         -0.14438123, -0.07243016],
#        ...,
#        [-0.05083593,  0.02510994, -0.15768604, ...,  0.1525963 ,
#          0.23367059, -0.03094891],
#        [-0.03681076,  0.01801717, -0.19822934, ..., -0.04061324,
#         -0.11218578,  0.22541872],
#        [-0.15221222,  0.26953474, -0.1986737 , ...,  0.03437556,
#          0.07468171,  0.06973902]], dtype=float32)

# %%
sample = embeddings[0]

sample.shape
# Out:
# (384,)

# %%
model = SemanticSignalSeparation(4, encoder=encoder, random_state=42)
doc_topic_matrix = model.fit_transform(abstracts, embeddings=embeddings)
# Out:
# Output()
# [08:34:59] Decomposition done.                                                                        ]8;id=30083;file:///usr/local/lib/python3.11/dist-packages/turftopic/models/decomp.py\decomp.py]8;;\:]8;id=874571;file:///usr/local/lib/python3.11/dist-packages/turftopic/models/decomp.py#144\144]8;;\
#            Term extraction done.                                                                      ]8;id=531853;file:///usr/local/lib/python3.11/dist-packages/turftopic/models/decomp.py\decomp.py]8;;\:]8;id=617597;file:///usr/local/lib/python3.11/dist-packages/turftopic/models/decomp.py#147\147]8;;\
# [08:35:09] Vocabulary encoded.                                                                        ]8;id=206346;file:///usr/local/lib/python3.11/dist-packages/turftopic/models/decomp.py\decomp.py]8;;\:]8;id=545771;file:///usr/local/lib/python3.11/dist-packages/turftopic/models/decomp.py#157\157]8;;\
#            Model fitting done.                                                                        ]8;id=105303;file:///usr/local/lib/python3.11/dist-packages/turftopic/models/decomp.py\decomp.py]8;;\:]8;id=777071;file:///usr/local/lib/python3.11/dist-packages/turftopic/models/decomp.py#170\170]8;;\
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>

# %%
model.print_topics(top_k=10)
# Out:
# ┏━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Topic ID ┃ Highest Ranking                                  ┃ Lowest Ranking                                    ┃
# ┡━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │        0 │ drugs, medicinal, treatments, doses, treatment,  │ gene, genes, genome, genetically, genomes,        │
# │          │ pharmaceutical, drug, alcohol, treated, treat    │ transcription, transcriptional, dna, rna, mrna    │
# ├──────────┼──────────────────────────────────────────────────┼───────────────────────────────────────────────────┤
# │        1 │ dietary, pathogen, diseases, healthy, disease,   │ crystal, atom, atoms, resonance, spectroscopy,    │
# │          │ pathogens, inflammation, flavonoids, extracts,   │ metal, phase, electronic, electron, chemistry     │
# │          │ infection                                        │                                                   │
# ├──────────┼──────────────────────────────────────────────────┼───────────────────────────────────────────────────┤
# │        2 │ ingredients, enzymes, esters, acids, organic,    │ patient, outcomes, symptoms, incidence, patients, │
# │          │ ester, aromatic, chemical, enzyme, compounds     │ diagnosed, syndrome, diagnostic, outcome,         │
# │          │                                                  │ severity                                          │
# ├──────────┼──────────────────────────────────────────────────┼───────────────────────────────────────────────────┤
# │        3 │ cancer, tumor, cancers, tumors, leukemia,        │ biomass, production, ecological, nature,          │
# │          │ antibodies, inhibitors, inflammation, antibody,  │ efficiency, environmental, accumulation, thermal, │
# │          │ cytokines                                        │ environment, enrichment                           │
# └──────────┴──────────────────────────────────────────────────┴───────────────────────────────────────────────────┘

# %%
model.plot_concept_compass(0, 1)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="f338b0d2-3fee-48ad-b983-c897db8b0db0" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f338b0d2-3fee-48ad-b983-c897db8b0db0")) {                    Plotly.newPlot(                        "f338b0d2-3fee-48ad-b983-c897db8b0db0",                        [{"hovertemplate":"x=%{x}\u003cbr\u003ey=%{y}\u003cbr\u003etext=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"black","symbol":"circle"},"mode":"text","name":"","orientation":"v","showlegend":false,"text":["molecular","molecular","molecular","atoms","atoms","atoms","atoms","atoms","atom","spectroscopy","resonance","crystal","crystal","crystal","crystal","crystal","metal","solvent","solvent","solvent","rna","molecular","molecular","molecular","molecule","atoms","atoms","atoms","atom","spectroscopy","resonance","resonance","crystal","metal","crystal","metal","solvent","solvent","solvent","compounds","rna","molecular","molecular","molecular","molecular","molecular","molecule","molecule","atom","spectroscopy","resonance","resonance","metal","metal","metal","solvent","solvent","solvent","compounds","compounds","rna","molecular","molecular","molecular","molecular","molecular","molecular","molecule","electron","electron","electronic","materials","chemistry","chemistry","metal","solvent","solvent","solvent","compounds","compounds","rna","rna","nucleotide","molecular","molecular","molecular","molecular","structure","coupling","molecules","electronic","ions","complexes","ether","solvent","solvent","solvent","compounds","compounds","compounds","rna","rna","nucleotide","nucleotide","nucleotide","molecular","molecular","nuclear","scattering","carbon","synthetic","volume","solid","chemical","solvents","solvent","compounds","compounds","compounds","compounds","rna","rna","rna","nucleotide","nucleotide","nucleotide","substrate","membranes","substrates","heterogeneous","synthesized","carbonyl","laser","derivative","compound","compounds","compounds","compounds","compounds","compounds","rna","rna","rna","nucleotide","nucleotide","nucleotide","formation","membrane","affinity","artificial","permeability","stage","ring","gas","liquid","formulation","compounds","compounds","compounds","drugs","rna","rna","rna","dna","nucleotide","nucleotide","formation","binding","dynamics","tandem","shaped","moiety","reaction","presentation","performed","procedures","formulation","pharmaceutical","pharmaceutical","drugs","genetically","rna","rna","dna","sequencing","nucleotide","morphological","layer","property","core","systematically","led","great","acetate","practical","crude","injection","pharmaceutical","pharmaceutical","drugs","genetically","genetically","rna","dna","sequencing","recombinant","morphological","similarity","databases","sensitivity","suppression","did","tools","removed","surgical","injection","undergoing","pharmaceutical","pharmaceutical","drugs","genetically","genetically","mrna","phylogenetic","evolution","differentiation","polymerase","mouse","variation","fields","14","decreasing","old","limited","carried","good","administered","doses","drug","drugs","genes","genetically","genomes","mrna","mutation","proliferation","biosynthesis","mitochondrial","neuronal","identification","reports","sources","superoxide","allowed","guidelines","hospital","alcohols","doses","treatments","drugs","genes","genome","genomes","genomic","cells","cell","antibody","diversity","growing","ranging","values","strength","improve","liver","pulmonary","alkaloids","patient","treated","treatments","drugs","gene","genes","transcription","biology","cells","species","populations","phenotypes","predominant","cancers","test","colon","multivariate","constituents","metabolites","efficacy","ther ...

# %%
# Topic Namer library
from turftopic.namers import LLMTopicNamer

# %%
# Costumize topic namer

# prompt = (
#   "  are naming topics for a machine learning research paper."
#   "Given these keywords: {keywords}, return a short and descriptive topic title."
#   "Limit to 2-3 words. Return only the topic name."
# )

# namer = LLMTopicNamer(
#     model_id="HuggingFaceTB/SmolLM2-1.7B-Instruct",
#     prompt_template=prompt,
#     max_keywords=10,
#     temperature=0
# )

# %%
namer = LLMTopicNamer("HuggingFaceTB/SmolLM2-1.7B-Instruct")
model.rename_topics(namer)

model.print_topics()
# Out:
# config.json:   0%|          | 0.00/908 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/3.42G [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/132 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/3.76k [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/801k [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/466k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/2.10M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/655 [00:00<?, ?B/s]
# Device set to use cpu
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ┏━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Topic ID ┃ Topic Name                      ┃ Highest Ranking                  ┃ Lowest Ranking                  ┃
# ┡━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │        0 │ Pain Management/Genetics        │ drugs, medicinal, treatments,    │ gene, genes, genome,            │
# │          │                                 │ doses, treatment                 │ genetically, genomes            │
# ├──────────┼─────────────────────────────────┼──────────────────────────────────┼─────────────────────────────────┤
# │        1 │ Dietary Supplements for         │ dietary, pathogen, diseases,     │ crystal, atom, atoms,           │
# │          │ Inflammation Reduction/crystal  │ healthy, disease                 │ resonance, spectroscopy         │
# │          │ spectroscopy                    │                                  │                                 │
# ├──────────┼─────────────────────────────────┼──────────────────────────────────┼─────────────────────────────────┤
# │        2 │ "Fermentation"/Patient outcomes │ ingredients, enzymes, esters,    │ patient, outcomes, symptoms,    │
# │          │ and diagnosis of a syndrome     │ acids, organic                   │ incidence, patients             │
# │          │ based on severity and symptoms. │                                  │                                 │
# ├──────────┼─────────────────────────────────┼──────────────────────────────────┼─────────────────────────────────┤
# │        3 │ Cancer Treatment/Sustainable    │ cancer, tumor, cancers, tumors,  │ biomass, production,            │
# │          │ Biomass Production              │ leukemia                         │ ecological, nature, efficiency  │
# └──────────┴─────────────────────────────────┴──────────────────────────────────┴─────────────────────────────────┘

# %%
model.rename_topics({
    0: "Topic0",
    1: "Topic1",
    2: "Topic2",
    3: "Topic4",
})

# %%
model.print_topic_distribution("I am a socialist and I am concerned with the growing inequality in our societies. I'd like to see governments do more to prevent the exploitation of workers.")
# Out:
# ┏━━━━━━━━━━━━┳━━━━━━━┓
# ┃ Topic name ┃ Score ┃
# ┡━━━━━━━━━━━━╇━━━━━━━┩
# │ Topic0     │  0.88 │
# │ Topic1     │ -0.21 │
# │ Topic4     │ -0.26 │
# │ Topic2     │ -0.86 │
# └────────────┴───────┘

# %%
df = pd.DataFrame(doc_topic_matrix, columns=model.topic_names)

fig = px.scatter_matrix(df, dimensions=model.topic_names, color="Topic0", template="plotly_white")
fig = fig.update_traces(diagonal_visible=False, showupperhalf=False, marker=dict(opacity=0.6))
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="4207d277-9e37-4b8b-8314-86eb4359e9a6" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("4207d277-9e37-4b8b-8314-86eb4359e9a6")) {                    Plotly.newPlot(                        "4207d277-9e37-4b8b-8314-86eb4359e9a6",                        [{"dimensions":[{"axis":{"matches":true},"label":"Topic0","values":[-0.28910905,0.7747843,1.7454499,1.623871,2.204364,0.3661364,0.5078907,1.0107905,0.9953492,-0.6387068,0.25252566,-0.5011094,0.61294174,0.62445873,-1.2170899,0.7578102,0.9990942,1.2740271,0.69536,-0.20742497,0.3745542,-0.8511536,1.2133385,-1.0950457,0.12719302,-0.056304753,-0.3983923,0.9629794,-0.7677246,-0.56362945,1.5044782,-0.6582969,-0.13187657,0.8801218,-1.6723825,1.4279624,-1.3367251,0.923492,-0.9026106,-0.7797023,-1.4552287,-0.57485086,0.004882434,0.37164733,0.59359646,-0.11749019,1.3145062,0.9449091,0.44608992,0.87020653,0.31364277,0.84796727,0.44592702,-1.5006527,1.2733573,0.37275374,-1.6705978,1.5644528,-1.6571989,1.5149871,0.42926824,-0.41742873,-0